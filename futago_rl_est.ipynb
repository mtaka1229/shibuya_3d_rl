# %% [markdown]
# 双子実験推定コードver1231

# %%
## 双子実験推定用ver1231
## 情報量em推定
## 観測分布・行動分布とも事象を条件付き分布に統一
## e-stepはQの更新，m-stepはQlogPの最大化によるsigma, thetaの同時推定
## 価値関数求解は構造化を外した

import pandas as pd
import os
import datetime
import numpy as np
from datetime import timedelta 
import csv
import time
import math
from scipy.stats import norm
from scipy.optimize import minimize
import random

start_time = time.time()
print('start!')
# Out:
# start!

# %%
############################
####### reading data #######
############################

## これはtheta = [-1.5, 1, 0.8], sigma = [2, 25]で推定した結果→これに寄せる結果が出るかどうか
## これはBLEデータね！！！経路データではないよ！！！
df_data = pd.read_csv('/Users/takahiromatsunaga/res2023/futago/generated_bledata.csv')

# search_folder = "/home/matsunaga/res2023/data/20230130_17/20230130_1745_18sec_end162021_under10_split/folder_10"
df_link = pd.read_csv('/Users/takahiromatsunaga/res2023/futago/df_link.csv')
df_node = pd.read_csv('/Users/takahiromatsunaga/res2023/futago/df_node.csv')
df_ble = pd.read_csv('/Users/takahiromatsunaga/res2023/futago/df_ble.csv')
df_demand = pd.read_csv('/Users/takahiromatsunaga/res2023/futago/df_demand.csv')
#file_list = list(os.listdir(search_folder))
L = len(df_link)
OD = len(df_demand)

# %%
############################
####### リンク接続行列 ####### ### 逆戻りと滞在ありの経路
############################

def Imaking(link_data): 
    n = len(link_data)
    I = np.eye(n) # 滞在
    for i in range(n):
        O = link_data.loc[i, 'o'] 
        D = link_data.loc[i, 'd'] 
        for j in range(n):
            if ((link_data.loc[j, 'o'] == O) or (link_data.loc[j, 'o'] == D)) or (link_data.loc[j, 'd'] == O) or (link_data.loc[j, 'd'] == D): 
                I[i, j] = 1
    return(I)

I = Imaking(df_link)

## スタートリンク25と吸収リンク26だけ操作
# リンク25(index24)へはどこからもいかない（スタート→スタートもない）
I[:, 24] = 0

# リンク26(index25)からは26にしかいかない
I[25, :] = 0
I[25, 25] = 1

# %%
#########################################
####### 吸収リンク＆タイムステップ設定 #######
#########################################

# 吸収はリンク26（index25, 仮想ノード17(100, 100, 0)に接続）のみ
ddata = [26]
D = len(ddata)

## param init：thetaとsigmaを合わせる
x = np.array((-1.5, 1, 0.8, 2, 25))

#assumed_x = np.array((-1.5, 1, 0.8)) # CC, DC, beta

## 観測パラメータ
#b = np.array((2, 25)) # N = b[0], sigma = b[1]
max_rssi = -40 ## これは固定して，この値は超えないように観測分布も与えるようにする

# 最短でT=7でスタートリンクから吸収リンクまで到達．
T = 10 # 試しに10で

# %%
##########################
###### 時空間プリズム ######
##########################
def TSNW(ODlist): # df_demandを与えれば良い
    Ilist = []

    # 起点Oからの到達可能性指示変数io
    Itlist = np.zeros((T, L, L)) ## これは各状態に対して与えるので遷移回数T-1よりひとつ多くてT成分考える（timestep数がTなら状態数はT）
    II = np.copy(I)
    Itlist[0, :, :] = np.eye(L) 

    for ts in range(1, T): 
        Itlist[ts, :, :] = II 
        II = np.dot(II, I)
        II = np.where(II > 0, 1, 0) 

    # 終点Dからの到達可能性指示変数id ## これもIlist同様の考え方
    Ittlist = np.zeros((T, L, L))
    for ts in range(T): 
        Ittlist[ts, :, :] = np.transpose(Itlist[T - ts - 1, :, :]) 

    for od in range(len(ODlist)):   

        # OD確定読み込み
        ao = ODlist.loc[od, 'o'] - 1  # index
        aabs = ODlist.loc[od, 'd'] - 1  # index
        #aabs = ODlist.loc[od, 'abs'] - 1
        #userid = df_demand.loc[od, 'userid']

        Id = np.zeros((T-1, L, L)) # Id[t]は時刻tの時の利用可能遷移k→aを示す．最後のt=T-1のとき不要なので要素数はt=0~T-2のT-1個

        for ts in range(T-1): # Tまでに吸収されるのでdはaabs．遷移回数はT-1なのでこれでOK
            if ts == 0:
                Id[ts, ao, :] = I[ao, :] 
                continue
            
            alist = np.where(Itlist[ts + 1, ao, :] == Ittlist[ts + 1, aabs, :])[0] ## ts=1（つまり第二回目の状態）のとき3番目の状態を見ている→OK
            ## Itlistの長さはT．最後はT-2で，そのときT-2+1=T-1, 
            for a in alist:
                if Itlist[ts + 1, ao, a] == Ittlist[ts + 1, aabs, a]: # always True
                    klist = np.where(I[:, a] == 1)[0]

                    for k in klist:
                        if len(np.where(Id[ts - 1, :, k] == 1)[0]) != 0:
                            Id[ts, k, a] = 1 

        Ilist.append(Id)
    
    return Ilist

# %%
###########################
######### 諸々の準備 ######## # 混雑やmax強度は一旦考慮しない
########################### 
# ビーコン周りの混雑はやるとしても属性として与える
# max_rssiはこちらで所与として与える？→生成させるrssiはそれを超えないようにする
# 理論値で与えるならそれなりに妥当な観測分布が得られると考えていいんか？

###### 各linkのoとdの座標を入れておく配列 ###### 
link_loc_array = [] 
for i in range(len(df_link)):
    linkid = df_link.loc[i, 'linkid']
    O = df_link.loc[i, 'o']
    D = df_link.loc[i, 'd']

    x_o = df_node[df_node['nodeid'] == O]['x'].iloc[0]
    y_o = df_node[df_node['nodeid'] == O]['y'].iloc[0]
    z_o = df_node[df_node['nodeid'] == O]['z'].iloc[0] 
    o_loc = np.array([x_o, y_o, z_o])

    x_d = df_node[df_node['nodeid'] == D]['x'].iloc[0]
    y_d = df_node[df_node['nodeid'] == D]['y'].iloc[0]
    z_d = df_node[df_node['nodeid'] == D]['z'].iloc[0]
    d_loc = np.array([x_d, y_d, z_d])

    loc_tuple = (o_loc, d_loc)
    link_loc_array.append(loc_tuple) 


###### 各ビーコンの座標を入れておく配列 ###### 
beacon_loc_array = []
for j in range(len(df_ble)):
    beacon_id = df_ble.loc[j, 'bleid']
    x_j = df_ble[df_ble['bleid'] == beacon_id]['x'].iloc[0]
    y_j = df_ble[df_ble['bleid'] == beacon_id]['y'].iloc[0]
    z_j = df_ble[df_ble['bleid'] == beacon_id]['z'].iloc[0]
    
    beacon_loc = np.array([x_j, y_j, z_j])
    beacon_loc_array.append(beacon_loc)


###### ビーコンとリンク線分の中点間距離を返す関数 ######
def dist_to_mid(p1, p2, x):
    p1 = np.array(p1)
    p2 = np.array(p2)
    x = np.array(x)

    segment = p2 - p1
    v1 = x - p1
    v2 = x - p2
    mid_point = (p1 + p2) / 2

    v = v1 - np.dot(v1, segment) / np.dot(segment, segment) * segment # 垂直ベクトルを計算
    distance = np.linalg.norm(x - mid_point)
    
    return distance


###### d_arrayの用意 ###### # 各リンクの中点とbleビーコンとの距離配列
d_array = np.zeros((len(df_link), len(df_ble)))
for i in range(len(df_link)):
    p_o = link_loc_array[i][0] # o座標 # i=1の時
    p_d = link_loc_array[i][1] # d座標

    for j in range(len(df_ble)):
        x_ap = df_ble.loc[j, 'x']
        y_ap = df_ble.loc[j, 'y']
        z_ap = df_ble.loc[j, 'z']
        p_ap = np.array([x_ap, y_ap, z_ap])

        d_array[i, j] = dist_to_mid(p_o, p_d, p_ap) # ijはlink i+1, ビーコンj+1の距離

# %%
#######################
####### 観測モデル ######
####################### ## odlistは，今回odが決まってるので不要ですね．

def qjx(rssi, x_loc, j, b):               # bは観測誤差分散のパラメータ．x_loc（x, y, z)にいたときビーコンjでrssiの観測が得られる確率
    j_loc = beacon_loc_array[j-1]                   # id=jのビーコンの位置座標
    #s = max_rssi
    d_est = 10 ** ((max_rssi - rssi)/(10*b[0]))     # 減衰パラメタb[0] rssi0→-40にしてみる
    d = np.linalg.norm(x_loc - j_loc) 
    f = norm.pdf(d, d_est, b[1])                    # 誤差分散b[1]
    omega = (100 + rssi) / 10 

    return omega * f


# -----****------Qを与える．Qはthetaとsigmaで決まる分布，同時推定なのでthetaとsigmaが両方xに入る-----****-----
def Mmodel(x, b):

    Pall = newPall(x)
    count = 0 
    
    SLlist = []
    TLlist = []

    grouped = df_data.groupby('d') # odで場合わけ．今回はdで分けることにする．不要だけど拡張を見据えて．
    df_list = [group.reset_index(drop = True) for name, group in grouped]

    for od in range(OD):
        TLodlist = []
        dfod = df_list[od] # 今回はこれしかないのでここで全データが読み込まれる
        Id = Ilist[od] # プリズムもodごとに1個に決まるのでみんな共通
        ao = int(dfod.loc[0, 'o']) - 1 # index 配分結果にo列与えてなかったわ
        #ao = dfod.loc[0, 'k'] - 1 
        aabs = int(dfod.loc[0, 'd']) - 1 # index

        grouped2 = dfod.groupby('userid')
        df_list2 = [group.reset_index(drop = True) for name, group in grouped2]

        for i in range(len(df_list2)): # 個人iに対して
            dfi = df_list2[i]
            ad = int(dfi.loc[len(dfi)-1, 'd']) - 1
                
            grouped3 = dfi.groupby('timestep')
            dfi_list = [group.reset_index(drop=True) for name, group in grouped3] ## 個人のデータをtimestepごとに分けている

            Ti = len(dfi_list)  ## ao入れるなら+1する必要(Ti<=9)のはず                    # 個人iの観測限界．時刻Tiでlast_linkに到達し，時刻Ti+1で吸収される

            #### 観測プリズム用意 #### odを与えたらプリズム制約．時刻TiつまりTi-1回の遷移でaoからadまで行く
            Idm = np.zeros((Ti-1, L, L)) ## 1成分目の値が遷移回数．Tiにするならabsまで行くことを仮定している．そのときItimlistは状態数＝時間数なのでTi+1で良い
            Itmlist = np.zeros((Ti, L, L))
            IIm = np.copy(I)
            Itmlist[0, :, :] = np.eye(L)

            for tt in range(1, Ti): 
                Itmlist[tt, :, :] = IIm 
                IIm = np.dot(IIm, I) 
                IIm = np.where(IIm > 0, 1, 0)

            Ittmlist = np.zeros((Ti, L, L))
            for tt in range(Ti): 
                Ittmlist[tt, :, :] = np.transpose(Itmlist[(Ti) - tt - 1, :, :])

            for tt in range(Ti-1):
                if tt == 0:
                    #print(ao)
                    Idm[tt, ao, :] = I[ao, :] 
                    #print('iketeruyo')
                    continue

                alist = np.where(Itmlist[tt + 1, ao, :] == Ittmlist[tt + 1, aabs, :])[0] # ここadじゃなくてaabsが適切では????
                for a in alist:
                    if Itmlist[tt + 1, ao, a] == Ittmlist[tt + 1, aabs, a]: # ここadじゃなくてaabsが適切では????
                        klist = np.where(I[:, a] == 1)[0] 

                        for k in klist:
                            if len(np.where(Idm[tt - 1, :, k] == 1)[0]) != 0:
                                Idm[tt, k, a] = 1 ### 時刻tにおいて，a(t)→a(t+1)への遷移がOKなところが1になっている                            

            #SLmatrix = np.zeros((T, L)) # status_likelihood 状態数は遷移数+1
            TLmatrix = np.zeros((T-1, L, L)) # trans likelihood
            pmmatrix = np.zeros((T-1, L, L))  # p(m|a)のmatrixのはず
            pmstmatrix = np.zeros((T-1, L, L)) # 同時発生尤度のマトリックス
            #SLmatrix[0, ao] = 1 # t = 0ではaoに確定的に存在するとする ####### ←ここがまずよくない．
            klist = [ao] # klistの初期値（oは確定）
            
            for t in range(1, T): #### t=tでは，k=a(t-1)からa=a(t)への遷移を考える．TLmatrixは遷移数＝T-1個しかないのでindexは0 ~ t-2

                #######################################
                ######### 1. 遷移発生尤度を計算 ########## # t=0はそもそもループから除かれている
                #######################################

                if t <= Ti - 1: ## この時間は遷移している．Ti<=t<=T-1では吸収されている

                    dfit = dfi_list[t] # Ti=len(dfi_list)+1としてしまっているのがよくない!!

                    ts = int(dfit.loc[0, 'timestep'])

                    it_grouped = dfit.groupby('bleid')
                    dfit_list = [it_group.reset_index(drop=True) for name, it_group in it_grouped]  

                    #slsum = 0
                    #nlist = np.argsort(SLmatrix[t-1])[::-1]  # tsにおける状態尤度が大きい順に並び替えたインデックスリスト
                    ## t=1のときSL[0]を参照するがaoしかないのでそのままaoを見ることになる．t=2のときSL[1]を参照，tのときt-1を参照
                    ## ループは1からまでにしてt-1における尤度が大きいリンクに対して??実装?
                    ## t-1で尤度大きいリンクをkとしてtのリンクをaとして扱った方が実態に近い
                    #klist = [] # つまり時刻t-1で状態尤度が高い上位のリンクをklistに入れている
                    #for i in range(L):
                    #    slsum += SLmatrix[t-1, nlist[i]]
                    #    klist.append(nlist[i])
                    #    if slsum >= 0.9:
                    #    break 
                    #klist3 = [i+1 for i in klist]
                    #print(f'時刻{t-1}での状態発生尤度の高かったリンクは{klist3}') ##

                    for k in klist: 

                        for a in range(L): ## tのリンクはこっち

                            if Idm[t-1, k, a] == 0: ### t-1時点でk→aが利用可能か否かを見る ###### 
                                TLmatrix[t-1, k, a] = 0 ### 多分これでいいのか？
                                continue

                            a_loc = link_loc_array[a]
                            a_o = a_loc[0]
                            a_d = a_loc[1]

                            ## 位置については一旦保留→aの上に確率的に存在するという仮定が望ましいが一旦リンクの中点にいるとする
                            x_loc = (a_o + a_d) / 2

                            pm = 1

                            ######## 全観測データを使う場合 ##########
                            """
                            for j in range(len(dfit)): ### ここでようやく各観測ログにアプローチ
                                ### rssi小さい観測がpmの極小化を招いている説もある，積をとっているので．
                                ### でも相対評価で尤度最大化しようとしているならそこまで気にならないはずだが
                                j_id = dfit.loc[j, 'ID']
                                j_rssi = dfit.loc[j, 'RSSI']
                                j_max_rssi = max_jt[j_id - 1, ts - 1] 

                                pm *= qjx(j_rssi, j_max_rssi, x_loc, j_id, b) # 観測方程式
                            """

                            ######### 各ビーコンで最大強度の観測データのみ使う場合 #########
                            ###### ビーコンごとにgroupbyしてその中でrssiが最大のログに対してpmを計算する
                            for j in range(len(dfit_list)):
                                dfitj = dfit_list[j]
                                j_id = int(dfitj.loc[0, 'bleid'])
                                # j_max_rssi = max_jt[j_id - 1, ts - 1] 
                                # dfitの中で，RSSI列が最大の要素のRSSIの値を取得
                                j_rssi = dfitj['rssi'].max()

                                pm *= qjx(j_rssi, x_loc, j_id, b) # 観測方程式

                            pmmatrix[t-1, k, a] = pm # 時刻tの観測尤度はリンクaの観測確率ね→ただしindexの関係でt-1に入れる．つまりt=1にat-1=a0=k→at=a1=aの観測尤度がpm[0]に入ってる
                            #print(f'時刻{t}でリンクa(t)つまり{a+1}の観測尤度{pm}')

                    # 遷移尤度のnume pmst 時刻tにおいてk(t-1)→a(t)への遷移が観測された確率がt-1に入ってる
                    # 時刻tにおいてk(t-1)→a(t)への遷移確率がPall[t-1]に入っている=時刻t-1にk(t-1)→a(t)に遷移する確率がPall[t-1]ということ
                    # つまり時刻tにおけるat→at+1への遷移確率はPall[t]に入っているということか．で，aT-1→aTへの遷移確率まで入っているがaT-2→aT-1までしか使わない
                    pmstmatrix[t-1, :, :] = pmmatrix[t-1, :, :] * Pall[od, t-1, :, :] # 観測確率pm*遷移確率（正規化前の観測尤度）

                    # 正規化
                    deno = np.sum(pmstmatrix[t-1, :, :], axis=1) # np.sum(pmstmatrix[t-1], axis=1)になってた
                    deno = (deno == 0) * 1 + (deno != 0) * deno ## 観測尤度の分母
                    
                    deno_rep = np.tile(deno, L).reshape(L, L).T ##### これがないと変になった

                    pmstmatrix[t-1, :, :] = pmstmatrix[t-1, :, :] / deno_rep ## これが観測尤度

                    #sl = SLmatrix[t-1, :] # このままでは行ベクトル
                    #sl_col = sl[:, None] #### ここがRと文法異なる部分

                    TLmatrix[t-1, :, :] = pmstmatrix[t-1, :, :] # * sl_col # 同時発生尤度を計算してる（SLmatrixはindexが1増えてるので，同じt-1でもひとつ前の段階を指名している
                    # 時刻tにk(a_t-1)からa(a_t)への遷移が発生する尤度

                    #### klist更新
                    klist = []
                    TLt = TLmatrix[t-1, :, :]
                    # 方法1: any() を使って非零の要素を持つ列を見つける
                    non_zero_columns = np.any(TLt != 0, axis=0)
                    klist = np.where(non_zero_columns)[0]

                    # 方法2: nonzero() を使って非零の要素がある列のインデックスを取得する
                    non_zero_indices = np.nonzero(np.any(TLt != 0, axis=0))[0]
                    klist = non_zero_indices.tolist()

                elif t == Ti:
                    TLmatrix[t-1, ad, aabs] = 1 ### それ以外はそのまま→0のまま
                
                else:
                    TLmatrix[t-1, aabs, aabs] = 1 ### それ以外はそのまま→0のまま

                ########################################
                ########## 2. 状態発生尤度を定義 ##########
                ########################################
                """
                if t <= Ti - 2: # 観測プリズム（ao, ad, Tiから決定）Idm内の状態しか取り得ない．k(a_t-1)からa(a_t)への遷移がOKのときIdmt[t-1]が1

                    dfit = dfi_list[t] # t<len(dfit)=Tiにおいて指定可能
                    ts = int(dfit.loc[0, 'timestep'])

                    for i in range(L): ## iは遷移先リンク，つまりa(t)の候補ということになる

                        klist = np.where(Idm[t-1, :, i] == 1)[0] ## 前時刻参照．時刻tにおいてリンクi=a(t)に遷移可能な前リンクk=a(t-1)を探し，klistに入れている．この時，構造化NWと観測情報からリンク候補はかなり絞られている

                        if len(klist) == 0:
                            continue

                        kTL = 0
                        for k in klist: # このiに移動できる元リンク（t-1時点でのリンクa(t-1)）
                            kTL += TLmatrix[t-1, k, i] ## 時刻t-1にk=a(t-1)からi = a(t)への遷移発生尤度をkTLに足していき，これがtでのiの存在尤度になる（それはそう！！）
                            #print(f'状態遷移 k = a(t-1) = {k+1} → a = a(t) = {i+1}（全部リンクid）の遷移発生尤度は{kTL}')

                        SLmatrix[t, i] = kTL ### SLmatrixはindex t に入れる（SL[0]を事前に定義済みなので）

                if t == Ti - 1: # この時刻で最終リンクに確定的に滞在
                    #print(f'時刻{t}で最後のリンク')
                    SLmatrix[t, ad] = 1

                elif t >= Ti: # この時刻以降は確定的に吸収に滞在
                    #print(f'時刻{t}で吸収リンク')             
                    SLmatrix[t, aabs] = 1
                """
            
            #SLlist.append(SLmatrix)
            TLodlist.append(TLmatrix)
        TLlist.append(TLodlist)

    return(TLlist)

# %%
###########################
####### 経路選択モデル ######
###########################

###### 即時効用行列 ###### # 混雑内生性考えないならT次元は圧縮可能だが一応→時不変だし，経路長も一緒だし経路パラメタしか入れてないので全リンクの効用が等しくなるよ．
def Mset(x): 
    #Probs_T = Probs.T # Probsを読み込む（内生性バージョン）
    inst = np.zeros((T-1, L, L))
    for t in range(T-1):
        inst_t = np.exp(df_link['cc'] * x[0] + df_link['dc'] * x[1])    ### + Probs_T[:, t] * x[1])    # + df_link['staire'] * x[1]) # + df_link_integrated['staire_with_esc'] * x[3])
        inst_t = pd.concat([inst_t]*L, axis=1) 
        inst_t = inst_t.T
        inst_t_numpy = inst_t.values # DataFrameをNumPy配列に変換
        inst[t, :, :] = inst_t_numpy

    return inst


###### リンク選択確率計算 ######
def newPall(x):
    Pall = np.zeros((OD, T-1, L, L)) # 個人ごと，時刻ごとの各リンク間遷移確率行列 遷移の回数なのでT-1．今回Tを状態の数としているので遷移数はT-1になる
    beta = x[-1]

    #### 以降odごとに処理 ####  ## dごとで選択確率が異なるので
    for od in range(OD): 
        
        Id = Ilist[od] # Ilistは配分計算実施時にTSNWから与える！． 
        ## 今odペアは一つしかないのでIlistは1つのみ

        ##### 即時効用 #####
        M = np.zeros((T-1, L, L))
        for ts in range(T-1):
            #print()
            Mts = Id[ts, :, :] * Mset(x)[ts, :, :] # 内生性考慮してないのでMsetは定常だが，内生性考慮時を想定してる
            M[ts, :, :] = Mts
        
        ##### 価値関数 ##### ### ここで価値関数求解（newVに相当）が入っている
        ##### 価値関数別で計算するならここにVを外から読み込むことになる
            
        z = np.ones((T, L))
        for t in range(T-1, 0, -1):
            ####
            zii = M[t-1, :, :] * (z[t, :] ** beta) 
            zi = zii.sum(axis = 1)
            z[t-1, :] = (zi==0)*1 + (zi!=0)*zi

        ##### 選択確率行列 ##### # 尤度計算は不要
        for t in range(T-1): # 選択確率は各時刻tごとに決まる
            for k in range(L):
                for a in range(L):
                    if M[t, k, a] == 0: # 接続条件を満たせなかった観測は排除（logzero回避）
                        continue # ここがbreakになってたのが癌だった
            
                    Pall[od, t, k, a] += np.exp(np.log(M[t, k, a]) + beta * np.log(z[t+1, a]) - np.log(z[t, k])) 
    return Pall # 個人ごとの各時刻ごとのリンク遷移確率の一覧がPallに入った

# %%
####################
####### em推定 ######
####################

def KL(x): 
    KL = 0

    theta = x[:3] # 経路長パラメタと時間割引率のみを想定
    sigma = x[3:] # 減衰定数と誤差分散

    Pt = newPall(theta) ## 経路選択モデルPの方はtheta未知変数

    ## Qのthetaは固定し，sigmaは動かして同時推定
    TLlist = Mmodel(y, sigma) ### ここで事前情報のthetaは固定するので前ステップの解yを採用．観測パラメータsigmaは変数化するのでx[2:]を入れる
    #### 前ステップでのtheta=yと未知パラメタsigmaから決まるQが得られる

    for od in range(OD): # 
        #userid = int(od_list.loc[od, 'userid'])
        TLodlist = TLlist[od]

        for i in range(len(TLodlist)): # 状態遷移発生尤度は個人ごとに変わるので個人ごとでループ回す
            TLmatrix = TLodlist[i]
            userid = i  ### 多分

            for t in range(T-1):
                KLit = 0
                pit = Pt[od, t, :, :] # 時刻tにk(a_t-1)とa(a_t)の同時滞在確率はpjoint[t-1]に入っている
                pit = (pit == 0) * 1 + (pit != 0) * pit

                for k in range(L): # 時刻tにa(t-1)からa(tへの遷移を考える)
                    for a in range(L):
                        logpka = 0

                        if pit[k, a] == 0:
                            logpka = 0
                            continue
                        
                        if TLmatrix[t, k, a] == 0:
                            continue

                        else:
                            p = pit[k, a] # 遷移確率
                            q = TLmatrix[t, k, a] # 遷移尤度
                            print(f'個人{userid}時刻{t}の{k+1}と{a+1}の同時滞在確率は{p}，同時発生尤度は{q}')
                        qlp = q * np.log(p)
                        qlq = q * np.log(q)

                        # KLPit += (qlq - qlp)
                        KLit += qlp # KLではなくなく交差エントロピー（対象事象が揃ったのでどっちもで計算できるはず）
                
                KL += KLit
                print(f'user{userid}，時刻{t}の一般化平均情報量{-KLit}（正，小さい方がいい）')

    print(f'モデルパラメタ{x}でのクロスエントロピー{-KL}')

    return -KL

# %%
# y = 前ステップのtheta：最初は，まあとりあえずy = np.array((-1.5, 1, 0.8))にする
y = np.array((-1.5, 1, 0.8))
Ilist = TSNW(df_demand)
print(KL(x))
# Out:
# 個人0時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9435953044072329
# 個人0時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.05640469559276702
# user0，時刻0の一般化平均情報量0.2326871904614013（正，小さい方がいい）
# 個人0時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9658124329263698
# 個人0時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.0341875670736302
# 個人0時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.9644060360859266
# 個人0時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.03559396391407343
# user0，時刻1の一般化平均情報量1.0567017490939528（正，小さい方がいい）
# 個人0時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.5661091945724861
# 個人0時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.43389080542751396
# 個人0時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.7067921336830113
# 個人0時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.2932078663169886
# 個人0時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.7067921336830114
# 個人0時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.2932078663169886
# 個人0時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9857239652622899
# 個人0時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.014276034737710103
# user0，時刻2の一般化平均情報量4.482751178181786（正，小さい方がいい）
# 個人0時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人0時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.3061154963991311
# 個人0時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.6938845036008688
# 個人0時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.987315921064883
# 個人0時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.01268407893511712
# 個人0時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.30611549639913105
# 個人0時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.693884503600869
# 個人0時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9873159210648829
# 個人0時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.012684078935117119
# 個人0時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user0，時刻3の一般化平均情報量6.974071511421946（正，小さい方がいい）
# 個人0時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人0時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.5377202040738549
# 個人0時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.46227979592614504
# 個人0時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人0時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人0時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.5377202040738549
# 個人0時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.4622797959261451
# 個人0時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user0，時刻4の一般化平均情報量8.521173337005514（正，小さい方がいい）
# 個人0時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人0時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人0時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人0時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user0，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人0時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人0時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user0，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人0時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user0，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人0時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user0，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人1時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9425599087957103
# 個人1時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.05744009120428983
# user1，時刻0の一般化平均情報量0.2348873045625493（正，小さい方がいい）
# user1，時刻1の一般化平均情報量0（正，小さい方がいい）
# user1，時刻2の一般化平均情報量0（正，小さい方がいい）
# user1，時刻3の一般化平均情報量0（正，小さい方がいい）
# user1，時刻4の一般化平均情報量0（正，小さい方がいい）
# user1，時刻5の一般化平均情報量0（正，小さい方がいい）
# 個人1時刻6の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user1，時刻6の一般化平均情報量-0.0（正，小さい方がいい）
# 個人1時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user1，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人1時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user1，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人2時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.8998309645467714
# 個人2時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.1001690354532286
# user2，時刻0の一般化平均情報量0.32568211933966923（正，小さい方がいい）
# 個人2時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.927257874128032
# 個人2時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.07274212587196804
# 個人2時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.9394042337439324
# 個人2時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.06059576625606757
# user2，時刻1の一般化平均情報量1.1794730747902167（正，小さい方がいい）
# 個人2時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.6755842810881773
# 個人2時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.3244157189118227
# 個人2時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.8597313759554152
# 個人2時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.14026862404458484
# 個人2時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.8597313759554152
# 個人2時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.14026862404458482
# 個人2時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9944652242853907
# 個人2時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.00553477571460922
# user2，時刻2の一般化平均情報量4.285443586014178（正，小さい方がいい）
# 個人2時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人2時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.323568766257602
# 個人2時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.676431233742398
# 個人2時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.9612260378316215
# 個人2時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.03877396216837847
# 個人2時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.323568766257602
# 個人2時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.6764312337423981
# 個人2時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9612260378316215
# 個人2時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.03877396216837847
# 個人2時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user2，時刻3の一般化平均情報量7.0750091044952965（正，小さい方がいい）
# 個人2時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人2時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.6758960718529633
# 個人2時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.32410392814703676
# 個人2時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人2時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人2時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.6758960718529632
# 個人2時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.32410392814703676
# 個人2時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user2，時刻4の一般化平均情報量8.432996721432584（正，小さい方がいい）
# 個人2時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人2時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人2時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人2時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user2，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人2時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人2時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user2，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人2時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user2，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人2時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user2，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人3時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9443945051412923
# 個人3時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.055605494858707576
# user3，時刻0の一般化平均情報量0.23098896730391089（正，小さい方がいい）
# user3，時刻1の一般化平均情報量0（正，小さい方がいい）
# user3，時刻2の一般化平均情報量0（正，小さい方がいい）
# user3，時刻3の一般化平均情報量0（正，小さい方がいい）
# user3，時刻4の一般化平均情報量0（正，小さい方がいい）
# user3，時刻5の一般化平均情報量0（正，小さい方がいい）
# 個人3時刻6の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user3，時刻6の一般化平均情報量-0.0（正，小さい方がいい）
# 個人3時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user3，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人3時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user3，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人4時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9243556787848604
# 個人4時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.07564432121513966
# user4，時刻0の一般化平均情報量0.27356950748255826（正，小さい方がいい）
# 個人4時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9407765649500657
# 個人4時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.05922343504993429
# 個人4時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.9413587958973078
# 個人4時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.05864120410269233
# user4，時刻1の一般化平均情報量1.1439795809428324（正，小さい方がいい）
# 個人4時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.6282432752981719
# 個人4時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.3717567247018282
# 個人4時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.8252492168238215
# 個人4時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.17475078317617856
# 個人4時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.8252492168238215
# 個人4時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.17475078317617854
# 個人4時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9927889702424239
# 個人4時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.0072110297575761935
# user4，時刻2の一般化平均情報量4.334638177217556（正，小さい方がいい）
# 個人4時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人4時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.2060697127179782
# 個人4時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.7939302872820219
# 個人4時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.9426124854026388
# 個人4時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.05738751459736116
# 個人4時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.20606971271797814
# 個人4時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.7939302872820219
# 個人4時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9426124854026389
# 個人4時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.05738751459736116
# 個人4時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user4，時刻3の一般化平均情報量6.862920373425718（正，小さい方がいい）
# 個人4時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人4時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.6112265045336901
# 個人4時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.3887734954663098
# 個人4時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人4時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人4時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.6112265045336902
# 個人4時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.3887734954663099
# 個人4時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user4，時刻4の一般化平均情報量8.474265458647213（正，小さい方がいい）
# 個人4時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人4時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人4時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人4時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user4，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人4時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人4時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user4，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人4時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user4，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人4時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user4，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人5時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9067463164003318
# 個人5時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.09325368359966826
# user5，時刻0の一般化平均情報量0.31098767505373964（正，小さい方がいい）
# 個人5時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9365508820143543
# 個人5時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.06344911798564573
# 個人5時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.9121812001225289
# 個人5時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.08781879987747122
# user5，時刻1の一般化平均情報量1.1867556641437695（正，小さい方がいい）
# 個人5時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.6490316567557334
# 個人5時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.3509683432442667
# 個人5時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.6516491169662728
# 個人5時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.3483508830337272
# 個人5時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.6516491169662728
# 個人5時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.3483508830337272
# 個人5時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9663729536575564
# 個人5時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.03362704634244369
# user5，時刻2の一般化平均情報量4.550038078938923（正，小さい方がいい）
# 個人5時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人5時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.16600937907703733
# 個人5時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.8339906209229626
# 個人5時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.8871142733853266
# 個人5時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.11288572661467348
# 個人5時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.16600937907703733
# 個人5時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.8339906209229627
# 個人5時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.8871142733853266
# 個人5時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.11288572661467348
# 個人5時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user5，時刻3の一般化平均情報量6.908886567785887（正，小さい方がいい）
# 個人5時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人5時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.9051428706178236
# 個人5時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.0948571293821764
# 個人5時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人5時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人5時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.9051428706178236
# 個人5時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.0948571293821764
# 個人5時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user5，時刻4の一般化平均情報量8.286703398503514（正，小さい方がいい）
# 個人5時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人5時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人5時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人5時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user5，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人5時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人5時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user5，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人5時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user5，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人5時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user5，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人6時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9507953072189481
# 個人6時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.04920469278105197
# user6，時刻0の一般化平均情報量0.21738789081393467（正，小さい方がいい）
# 個人6時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.8725000110837001
# 個人6時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.12749998891629985
# 個人6時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.9436364791625346
# 個人6時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.05636352083746534
# user6，時刻1の一般化平均情報量1.3097665428098826（正，小さい方がいい）
# 個人6時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.4972048412752133
# 個人6時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.5027951587247866
# 個人6時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.7312074356737446
# 個人6時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.2687925643262555
# 個人6時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.7312074356737447
# 個人6時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.2687925643262554
# 個人6時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9619200950887764
# 個人6時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.0380799049112236
# user6，時刻2の一般化平均情報量4.508096215440946（正，小さい方がいい）
# 個人6時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人6時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.2989846676600398
# 個人6時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.7010153323399603
# 個人6時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.9448374922636473
# 個人6時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.05516250773635261
# 個人6時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.2989846676600398
# 個人6時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.7010153323399603
# 個人6時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9448374922636474
# 個人6時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.05516250773635261
# 個人6時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user6，時刻3の一般化平均情報量7.060699039192346（正，小さい方がいい）
# 個人6時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人6時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.6243469690290333
# 個人6時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.37565303097096675
# 個人6時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人6時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人6時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.6243469690290333
# 個人6時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.37565303097096675
# 個人6時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user6，時刻4の一般化平均情報量8.465892664088082（正，小さい方がいい）
# 個人6時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人6時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人6時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人6時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user6，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人6時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人6時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user6，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人6時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user6，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人6時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user6，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人7時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9298835308267746
# 個人7時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.07011646917322543
# user7，時刻0の一般化平均情報量0.26182336418126684（正，小さい方がいい）
# user7，時刻1の一般化平均情報量0（正，小さい方がいい）
# user7，時刻2の一般化平均情報量0（正，小さい方がいい）
# user7，時刻3の一般化平均情報量0（正，小さい方がいい）
# user7，時刻4の一般化平均情報量0（正，小さい方がいい）
# user7，時刻5の一般化平均情報量0（正，小さい方がいい）
# 個人7時刻6の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user7，時刻6の一般化平均情報量-0.0（正，小さい方がいい）
# 個人7時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user7，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人7時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user7，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人8時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9454248971117314
# 個人8時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.054575102888268626
# user8，時刻0の一般化平均情報量0.22879948544920392（正，小さい方がいい）
# 個人8時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9243626918873691
# 個人8時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.07563730811263106
# 個人8時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.9270222914058426
# 個人8時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.07297770859415746
# user8，時刻1の一般化平均情報量1.2003422281504474（正，小さい方がいい）
# 個人8時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.5158276616643376
# 個人8時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.48417233833566237
# 個人8時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.7784220711814905
# 個人8時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.2215779288185095
# 個人8時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.7784220711814905
# 個人8時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.22157792881850946
# 個人8時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9673530318439394
# 個人8時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.032646968156060656
# user8，時刻2の一般化平均情報量4.446589349260798（正，小さい方がいい）
# 個人8時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人8時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.31596340008017404
# 個人8時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.6840365999198259
# 個人8時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.9731292295477483
# 個人8時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.026870770452251672
# 個人8時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.31596340008017404
# 個人8時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.684036599919826
# 個人8時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9731292295477483
# 個人8時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.026870770452251672
# 個人8時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user8，時刻3の一般化平均情報量7.029739077671273（正，小さい方がいい）
# 個人8時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人8時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.7525992295801621
# 個人8時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.24740077041983788
# 個人8時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人8時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人8時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.7525992295801621
# 個人8時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.24740077041983788
# 個人8時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user8，時刻4の一般化平均情報量8.384048775884285（正，小さい方がいい）
# 個人8時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人8時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人8時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人8時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user8，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人8時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人8時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user8，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人8時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user8，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人8時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user8，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人9時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9440141909792231
# 個人9時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.05598580902077682
# user9，時刻0の一般化平均情報量0.23179709758911093（正，小さい方がいい）
# user9，時刻1の一般化平均情報量0（正，小さい方がいい）
# user9，時刻2の一般化平均情報量0（正，小さい方がいい）
# user9，時刻3の一般化平均情報量0（正，小さい方がいい）
# user9，時刻4の一般化平均情報量0（正，小さい方がいい）
# user9，時刻5の一般化平均情報量0（正，小さい方がいい）
# 個人9時刻6の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user9，時刻6の一般化平均情報量-0.0（正，小さい方がいい）
# 個人9時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user9，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人9時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user9，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人10時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9358930575414033
# 個人10時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.06410694245859679
# user10，時刻0の一般化平均情報量0.24905370945322114（正，小さい方がいい）
# 個人10時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9470086302922365
# 個人10時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.05299136970776349
# 個人10時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.9378467037003436
# 個人10時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.06215329629965638
# user10，時刻1の一般化平均情報量1.1325115542117925（正，小さい方がいい）
# 個人10時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.6501196713831104
# 個人10時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.34988032861688956
# 個人10時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.9038976569759518
# 個人10時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.0961023430240482
# 個人10時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.9038976569759518
# 個人10時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.09610234302404819
# 個人10時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9978814736352176
# 個人10時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.002118526364782383
# user10，時刻2の一般化平均情報量4.24010560801124（正，小さい方がいい）
# 個人10時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人10時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.26696902414239243
# 個人10時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.7330309758576076
# 個人10時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.8754061405854814
# 個人10時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.12459385941451862
# 個人10時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.2669690241423924
# 個人10時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.7330309758576076
# 個人10時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.8754061405854813
# 個人10時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.1245938594145186
# 個人10時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user10，時刻3の一般化平均情報量7.157780444363601（正，小さい方がいい）
# 個人10時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人10時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.7451785747558877
# 個人10時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.2548214252441123
# 個人10時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人10時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人10時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.7451785747558878
# 個人10時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.2548214252441123
# 個人10時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user10，時刻4の一般化平均情報量8.388784249873023（正，小さい方がいい）
# 個人10時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人10時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人10時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人10時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user10，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人10時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人10時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user10，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人10時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user10，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人10時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user10，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人11時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.8908870939246413
# 個人11時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.10911290607535865
# user11，時刻0の一般化平均情報量0.3446869670091033（正，小さい方がいい）
# 個人11時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.7163916452228869
# 個人11時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.28360835477711316
# 個人11時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.7928563923557974
# 個人11時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.2071436076442026
# user11，時刻1の一般化平均情報量1.8618204038807846（正，小さい方がいい）
# 個人11時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.3769505291696307
# 個人11時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.6230494708303694
# 個人11時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.6539848459564566
# 個人11時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.34601515404354344
# 個人11時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.6539848459564567
# 個人11時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.3460151540435434
# 個人11時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9638683096780826
# 個人11時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.03613169032191751
# user11，時刻2の一般化平均情報量4.613073983221893（正，小さい方がいい）
# 個人11時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人11時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.3025766054329344
# 個人11時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.6974233945670655
# 個人11時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.926218596308115
# 個人11時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.07378140369188493
# 個人11時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.3025766054329344
# 個人11時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.6974233945670656
# 個人11時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9262185963081151
# 個人11時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.07378140369188495
# 個人11時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user11，時刻3の一般化平均情報量7.113355017262682（正，小さい方がいい）
# 個人11時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人11時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.6560440407106677
# 個人11時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.3439559592893323
# 個人11時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人11時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人11時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.6560440407106677
# 個人11時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.3439559592893323
# 個人11時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user11，時刻4の一般化平均情報量8.445665249928272（正，小さい方がいい）
# 個人11時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人11時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人11時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人11時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user11，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人11時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人11時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user11，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人11時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user11，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人11時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user11，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人12時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9380259729613419
# 個人12時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.061974027038658085
# user12，時刻0の一般化平均情報量0.24452147342697278（正，小さい方がいい）
# user12，時刻1の一般化平均情報量0（正，小さい方がいい）
# user12，時刻2の一般化平均情報量0（正，小さい方がいい）
# user12，時刻3の一般化平均情報量0（正，小さい方がいい）
# user12，時刻4の一般化平均情報量0（正，小さい方がいい）
# user12，時刻5の一般化平均情報量0（正，小さい方がいい）
# 個人12時刻6の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user12，時刻6の一般化平均情報量-0.0（正，小さい方がいい）
# 個人12時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user12，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人12時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user12，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人13時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9531558943060802
# 個人13時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.0468441056939198
# user13，時刻0の一般化平均情報量0.21237187482971692（正，小さい方がいい）
# 個人13時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9315447749443003
# 個人13時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.06845522505569969
# 個人13時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.92933210136509
# 個人13時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.07066789863490991
# user13，時刻1の一般化平均情報量1.180075537224511（正，小さい方がいい）
# 個人13時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.6001162838313725
# 個人13時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.39988371616862745
# 個人13時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.858799472847001
# 個人13時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.141200527152999
# 個人13時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.858799472847001
# 個人13時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.14120052715299894
# 個人13時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9950138713735044
# 個人13時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.004986128626495628
# user13，時刻2の一般化平均情報量4.302738915155714（正，小さい方がいい）
# 個人13時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人13時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.16195714865521876
# 個人13時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.8380428513447813
# 個人13時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.9317262085662416
# 個人13時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.06827379143375838
# 個人13時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.16195714865521874
# 個人13時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.8380428513447813
# 個人13時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9317262085662417
# 個人13時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.06827379143375838
# 個人13時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user13，時刻3の一般化平均情報量6.792676464529076（正，小さい方がいい）
# 個人13時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人13時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.4478490101816461
# 個人13時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.5521509898183539
# 個人13時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人13時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人13時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.44784901018164613
# 個人13時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.5521509898183539
# 個人13時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user13，時刻4の一般化平均情報量8.578524434865685（正，小さい方がいい）
# 個人13時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人13時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人13時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人13時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user13，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人13時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人13時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user13，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人13時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user13，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人13時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user13，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人14時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.942105096110175
# 個人14時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.0578949038898249
# user14，時刻0の一般化平均情報量0.23585373690173508（正，小さい方がいい）
# 個人14時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9330688343817299
# 個人14時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.06693116561827014
# 個人14時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.9441148313114387
# 個人14時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.05588516868856139
# user14，時刻1の一般化平均情報量1.1599238626197148（正，小さい方がいい）
# 個人14時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.42054025093846087
# 個人14時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.5794597490615392
# 個人14時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.7225884974041006
# 個人14時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.2774115025958995
# 個人14時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.7225884974041006
# 個人14時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.2774115025958994
# 個人14時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9697768568555327
# 個人14時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.030223143144467307
# user14，時刻2の一般化平均情報量4.522884211014101（正，小さい方がいい）
# 個人14時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人14時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.29240398538673074
# 個人14時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.7075960146132693
# 個人14時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.9346810949490043
# 個人14時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.06531890505099563
# 個人14時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.2924039853867307
# 個人14時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.7075960146132694
# 個人14時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9346810949490044
# 個人14時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.06531890505099563
# 個人14時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user14，時刻3の一般化平均情報量7.070751844279754（正，小さい方がいい）
# 個人14時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人14時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.6308521681861021
# 個人14時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.3691478318138979
# 個人14時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人14時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人14時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.6308521681861021
# 個人14時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.3691478318138979
# 個人14時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user14，時刻4の一般化平均情報量8.461741386050043（正，小さい方がいい）
# 個人14時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人14時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人14時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人14時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user14，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人14時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人14時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user14，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人14時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user14，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人14時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user14，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人15時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9243793987972531
# 個人15時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.07562060120274695
# user15，時刻0の一般化平均情報量0.27351910478318053（正，小さい方がいい）
# 個人15時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9031367520768743
# 個人15時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.09686324792312578
# 個人15時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.8758313474940628
# 個人15時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.12416865250593714
# user15，時刻1の一般化平均情報量1.3094404064701466（正，小さい方がいい）
# 個人15時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.6900592965802089
# 個人15時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.30994070341979096
# 個人15時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.8534777415307393
# 個人15時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.14652225846926062
# 個人15時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.8534777415307393
# 個人15時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.14652225846926062
# 個人15時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9940488048359051
# 個人15時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.005951195164094865
# user15，時刻2の一般化平均情報量4.289295962428694（正，小さい方がいい）
# 個人15時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人15時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.23866108897032548
# 個人15時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.7613389110296744
# 個人15時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.9686401106939874
# 個人15時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.03135988930601261
# 個人15時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.2386610889703255
# 個人15時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.7613389110296745
# 個人15時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9686401106939874
# 個人15時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.031359889306012606
# 個人15時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user15，時刻3の一般化平均情報量6.871541325274814（正，小さい方がいい）
# 個人15時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人15時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.8333500844598666
# 個人15時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.16664991554013334
# 個人15時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人15時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人15時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.8333500844598667
# 個人15時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.16664991554013336
# 個人15時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user15，時刻4の一般化平均情報量8.332517801609558（正，小さい方がいい）
# 個人15時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人15時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人15時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人15時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user15，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人15時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人15時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user15，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人15時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user15，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人15時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user15，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人16時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9119514804512764
# 個人16時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.08804851954872356
# user16，時刻0の一般化平均情報量0.299927212077246（正，小さい方がいい）
# 個人16時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9271837339430369
# 個人16時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.07281626605696324
# 個人16時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.731981356218934
# 個人16時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.2680186437810659
# user16，時刻1の一般化平均情報量1.4096957900605793（正，小さい方がいい）
# 個人16時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.5265240426859811
# 個人16時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.4734759573140189
# 個人16時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.7195871748309457
# 個人16時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.2804128251690543
# 個人16時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.7195871748309457
# 個人16時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.28041282516905425
# 個人16時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9785563559661327
# 個人16時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.02144364403386731
# user16，時刻2の一般化平均情報量4.488981389379738（正，小さい方がいい）
# 個人16時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人16時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.4525994851029336
# 個人16時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.5474005148970664
# 個人16時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.9666808891725802
# 個人16時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.03331911082741973
# 個人16時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.4525994851029336
# 個人16時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.5474005148970664
# 個人16時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9666808891725803
# 個人16時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.033319110827419736
# 個人16時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user16，時刻3の一般化平均情報量7.343972795447198（正，小さい方がいい）
# 個人16時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人16時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.8037354381687688
# 個人16時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.19626456183123106
# 個人16時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人16時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人16時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.8037354381687688
# 個人16時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.1962645618312311
# 個人16時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user16，時刻4の一般化平均情報量8.351416320745425（正，小さい方がいい）
# 個人16時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人16時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人16時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人16時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user16，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人16時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人16時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user16，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人16時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user16，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人16時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user16，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人17時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9417550073970549
# 個人17時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.058244992602945085
# user17，時刻0の一般化平均情報量0.23659764107306497（正，小さい方がいい）
# 個人17時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9679978476303003
# 個人17時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.03200215236969975
# 個人17時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.9884991771535131
# 個人17時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.011500822846486795
# user17，時刻1の一般化平均情報量1.0245941203924018（正，小さい方がいい）
# 個人17時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.6280103800314272
# 個人17時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.3719896199685727
# 個人17時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.8500586759944201
# 個人17時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.14994132400557983
# 個人17時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.8500586759944202
# 個人17時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.14994132400557983
# 個人17時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9941234266724647
# 個人17時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.005876573327535288
# user17，時刻2の一般化平均情報量4.306839537310559（正，小さい方がいい）
# 個人17時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人17時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.3612891440350967
# 個人17時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.6387108559649033
# 個人17時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.9731635357702064
# 個人17時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.026836464229793487
# 個人17時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.3612891440350966
# 個人17時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.6387108559649033
# 個人17時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9731635357702065
# 個人17時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.02683646422979349
# 個人17時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user17，時刻3の一般化平均情報量7.12874868726291（正，小さい方がいい）
# 個人17時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人17時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.8450973727480545
# 個人17時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.15490262725194545
# 個人17時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人17時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人17時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.8450973727480545
# 個人17時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.15490262725194545
# 個人17時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user17，時刻4の一般化平均情報量8.325021296322053（正，小さい方がいい）
# 個人17時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人17時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人17時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人17時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user17，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人17時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人17時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user17，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人17時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user17，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人17時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user17，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人18時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9591769394520618
# 個人18時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.040823060547938154
# user18，時刻0の一般化平均情報量0.19957774456501565（正，小さい方がいい）
# 個人18時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9030385037859874
# 個人18時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.09696149621401261
# 個人18時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.8613646630570033
# 個人18時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.13863533694299665
# user18，時刻1の一般化平均情報量1.325726714105302（正，小さい方がいい）
# 個人18時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.5359778002655909
# 個人18時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.464022199734409
# 個人18時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.7359454419873036
# 個人18時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.26405455801269634
# 個人18時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.7359454419873037
# 個人18時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.26405455801269634
# 個人18時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9569303221767069
# 個人18時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.04306967782329314
# user18，時刻2の一般化平均情報量4.501723345451543（正，小さい方がいい）
# 個人18時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人18時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.42711952530189734
# 個人18時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.5728804746981025
# 個人18時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.9947443858515014
# 個人18時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.005255614148498543
# 個人18時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.42711952530189734
# 個人18時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.5728804746981028
# 個人18時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9947443858515015
# 個人18時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.005255614148498543
# 個人18時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user18，時刻3の一般化平均情報量7.220737907440116（正，小さい方がいい）
# 個人18時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人18時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.6271945474887521
# 個人18時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.37280545251124775
# 個人18時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人18時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人18時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.6271945474887523
# 個人18時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.3728054525112478
# 個人18時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user18，時刻4の一般化平均情報量8.464075488374318（正，小さい方がいい）
# 個人18時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人18時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人18時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人18時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user18，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人18時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人18時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user18，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人18時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user18，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人18時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user18，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人19時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9519622422289626
# 個人19時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.04803775777103738
# user19，時刻0の一般化平均情報量0.21490826839513733（正，小さい方がいい）
# 個人19時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9538621352677946
# 個人19時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.0461378647322053
# 個人19時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.5798657377602657
# 個人19時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.4201342622397343
# user19，時刻1の一般化平均情報量1.5126311877671559（正，小さい方がいい）
# 個人19時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.48434775112509654
# 個人19時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.5156522488749034
# 個人19時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.7648055226566635
# 個人19時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.23519447734333643
# 個人19時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.7648055226566636
# 個人19時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.23519447734333646
# 個人19時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9673484689593551
# 個人19時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.03265153104064489
# user19，時刻2の一般化平均情報量4.467947152713939（正，小さい方がいい）
# 個人19時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人19時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.47693017020645867
# 個人19時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.5230698297935413
# 個人19時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.945331570218135
# 個人19時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.054668429781865
# 個人19時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.4769301702064586
# 個人19時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.5230698297935414
# 個人19時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9453315702181351
# 個人19時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.05466842978186501
# 個人19時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user19，時刻3の一般化平均情報量7.4485385877768815（正，小さい方がいい）
# 個人19時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人19時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.862236162583638
# 個人19時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.137763837416362
# 個人19時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人19時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人19時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.862236162583638
# 個人19時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.137763837416362
# 個人19時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user19，時刻4の一般化平均情報量8.31408421659165（正，小さい方がいい）
# 個人19時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人19時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人19時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人19時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user19，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人19時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人19時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user19，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人19時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user19，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人19時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user19，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人20時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9484763953941675
# 個人20時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.05152360460583249
# user20，時刻0の一般化平均情報量0.22231535095403981（正，小さい方がいい）
# user20，時刻1の一般化平均情報量0（正，小さい方がいい）
# user20，時刻2の一般化平均情報量0（正，小さい方がいい）
# user20，時刻3の一般化平均情報量0（正，小さい方がいい）
# user20，時刻4の一般化平均情報量0（正，小さい方がいい）
# user20，時刻5の一般化平均情報量0（正，小さい方がいい）
# 個人20時刻6の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user20，時刻6の一般化平均情報量-0.0（正，小さい方がいい）
# 個人20時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user20，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人20時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user20，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人21時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9606356160530424
# 個人21時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.03936438394695757
# user21，時刻0の一般化平均情報量0.19647819988555543（正，小さい方がいい）
# 個人21時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9621670307800183
# 個人21時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.037832969219981694
# 個人21時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.9305362637052892
# 個人21時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.0694637362947108
# user21，時刻1の一般化平均情報量1.10325114844356（正，小さい方がいい）
# 個人21時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.7240291036245421
# 個人21時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.27597089637545796
# 個人21時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.8546796202133894
# 個人21時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.14532037978661058
# 個人21時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.8546796202133895
# 個人21時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.14532037978661058
# 個人21時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.8574075715567963
# 個人21時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.14259242844320372
# user21，時刻2の一般化平均情報量4.482216483083781（正，小さい方がいい）
# 個人21時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人21時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.17607119390890855
# 個人21時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.8239288060910914
# 個人21時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.8845593731374768
# 個人21時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.11544062686252315
# 個人21時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.17607119390890855
# 個人21時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.8239288060910915
# 個人21時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.8845593731374768
# 個人21時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.11544062686252315
# 個人21時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user21，時刻3の一般化平均情報量6.937031866274606（正，小さい方がいい）
# 個人21時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人21時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.47492858828317436
# 個人21時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.5250714117168256
# 個人21時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人21時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人21時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.47492858828317436
# 個人21時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.5250714117168256
# 個人21時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user21，時刻4の一般化平均情報量8.561243663725872（正，小さい方がいい）
# 個人21時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人21時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人21時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人21時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user21，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人21時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人21時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user21，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人21時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user21，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人21時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user21，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人22時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9339206463011831
# ...
# 個人92時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.20064712768270265
# 個人92時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user92，時刻4の一般化平均情報量8.354213045170026（正，小さい方がいい）
# 個人92時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人92時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人92時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人92時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user92，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人92時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人92時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user92，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人92時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user92，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人92時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user92，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人93時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9152210625725392
# 個人93時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.08477893742746082
# user93，時刻0の一般化平均情報量0.29297967081881654（正，小さい方がいい）
# 個人93時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.8875856827386502
# 個人93時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.11241431726134979
# 個人93時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.9428721757581086
# 個人93時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.05712782424189132
# user93，時刻1の一般化平均情報量1.2734255084407862（正，小さい方がいい）
# 個人93時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.5419697791788133
# 個人93時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.45803022082118666
# 個人93時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.8011018790247276
# 個人93時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.19889812097527226
# 個人93時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.8011018790247277
# 個人93時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.19889812097527226
# 個人93時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9854032609137955
# 個人93時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.01459673908620451
# user93，時刻2の一般化平均情報量4.390326755486775（正，小さい方がいい）
# 個人93時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人93時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.3267971870462027
# 個人93時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.6732028129537974
# 個人93時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.9326379912600435
# 個人93時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.06736200873995654
# 個人93時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.3267971870462026
# 個人93時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.6732028129537974
# 個人93時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9326379912600433
# 個人93時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.06736200873995654
# 個人93時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user93，時刻3の一般化平均情報量7.150859417052999（正，小さい方がいい）
# 個人93時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人93時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.537957143361616
# 個人93時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.462042856638384
# 個人93時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人93時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人93時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.537957143361616
# 個人93時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.4620428566383839
# 個人93時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user93，時刻4の一般化平均情報量8.521022134738239（正，小さい方がいい）
# 個人93時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人93時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人93時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人93時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user93，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人93時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人93時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user93，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人93時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user93，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人93時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user93，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人94時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9603198867598404
# 個人94時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.039680113240159604
# user94，時刻0の一般化平均情報量0.19714909366025246（正，小さい方がいい）
# user94，時刻1の一般化平均情報量0（正，小さい方がいい）
# user94，時刻2の一般化平均情報量0（正，小さい方がいい）
# user94，時刻3の一般化平均情報量0（正，小さい方がいい）
# user94，時刻4の一般化平均情報量0（正，小さい方がいい）
# user94，時刻5の一般化平均情報量0（正，小さい方がいい）
# 個人94時刻6の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user94，時刻6の一般化平均情報量-0.0（正，小さい方がいい）
# 個人94時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user94，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人94時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user94，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人95時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.8511111344263479
# 個人95時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.14888886557365208
# user95，時刻0の一般化平均情報量0.42920697888183923（正，小さい方がいい）
# 個人95時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.7586845237766262
# 個人95時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.24131547622337376
# 個人95時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.8036494156051803
# 個人95時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.19635058439481964
# user95，時刻1の一般化平均情報量1.7455915839618814（正，小さい方がいい）
# 個人95時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.21136149416414568
# 個人95時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.7886385058358543
# 個人95時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.6139497558634138
# 個人95時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.3860502441365861
# 個人95時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.6139497558634139
# 個人95時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.3860502441365862
# 個人95時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9777384461625527
# 個人95時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.022261553837447278
# user95，時刻2の一般化平均情報量4.671937777689654（正，小さい方がいい）
# 個人95時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人95時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.31085467586202287
# 個人95時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.6891453241379771
# 個人95時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.8511884224672346
# 個人95時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.1488115775327654
# 個人95時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.31085467586202287
# 個人95時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.6891453241379772
# 個人95時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.8511884224672346
# 個人95時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.1488115775327654
# 個人95時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user95，時刻3の一般化平均情報量7.3120000590562055（正，小さい方がいい）
# 個人95時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人95時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.7332496683357276
# 個人95時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.26675033166427237
# 個人95時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人95時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人95時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.7332496683357276
# 個人95時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.2667503316642724
# 個人95時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user95，時刻4の一般化平均情報量8.396396654358135（正，小さい方がいい）
# 個人95時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人95時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人95時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人95時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user95，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人95時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人95時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user95，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人95時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user95，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人95時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user95，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人96時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9432486177289029
# 個人96時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.05675138227109706
# user96，時刻0の一般化平均情報量0.23342386564254514（正，小さい方がいい）
# 個人96時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9498249222676457
# 個人96時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.05017507773235423
# 個人96時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.8375384924630142
# 個人96時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.16246150753698585
# user96，時刻1の一般化平均情報量1.2368145921273883（正，小さい方がいい）
# 個人96時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.3659769067429273
# 個人96時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.6340230932570726
# 個人96時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.7513851908076002
# 個人96時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.24861480919239975
# 個人96時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.7513851908076002
# 個人96時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.2486148091923997
# 個人96時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9780798097130686
# 個人96時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.021920190286931384
# user96，時刻2の一般化平均情報量4.492965285560228（正，小さい方がいい）
# 個人96時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人96時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.08506659629454615
# 個人96時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.9149334037054538
# 個人96時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.8703844189331993
# 個人96時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.12961558106680074
# 個人96時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.08506659629454612
# 個人96時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.9149334037054538
# 個人96時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.8703844189331993
# 個人96時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.1296155810668007
# 個人96時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user96，時刻3の一般化平均情報量6.772185180250961（正，小さい方がいい）
# 個人96時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人96時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.49150688384884855
# 個人96時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.5084931161511513
# 個人96時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人96時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人96時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.49150688384884855
# 個人96時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.5084931161511514
# 個人96時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user96，時刻4の一般化平均情報量8.550664262138284（正，小さい方がいい）
# 個人96時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人96時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人96時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人96時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user96，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人96時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人96時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user96，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人96時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user96，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人96時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user96，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人97時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9270038654633862
# 個人97時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.07299613453661379
# user97，時刻0の一般化平均情報量0.26794237058043446（正，小さい方がいい）
# user97，時刻1の一般化平均情報量0（正，小さい方がいい）
# user97，時刻2の一般化平均情報量0（正，小さい方がいい）
# user97，時刻3の一般化平均情報量0（正，小さい方がいい）
# user97，時刻4の一般化平均情報量0（正，小さい方がいい）
# user97，時刻5の一般化平均情報量0（正，小さい方がいい）
# 個人97時刻6の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user97，時刻6の一般化平均情報量-0.0（正，小さい方がいい）
# 個人97時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user97，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人97時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user97，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人98時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.8934603385820535
# 個人98時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.10653966141794646
# user98，時刻0の一般化平均情報量0.3392190745499594（正，小さい方がいい）
# 個人98時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.8184218237372762
# 個人98時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.18157817626272382
# 個人98時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.8179000048094466
# 個人98時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.18209999519055342
# user98，時刻1の一般化平均情報量1.582524805862016（正，小さい方がいい）
# 個人98時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.057330876041145694
# 個人98時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.9426691239588543
# 個人98時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.37897013542257224
# 個人98時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.6210298645774278
# 個人98時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.37897013542257224
# 個人98時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.6210298645774277
# 個人98時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.911231353164314
# 個人98時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.08876864683568589
# user98，時刻2の一般化平均情報量5.050289688255936（正，小さい方がいい）
# 個人98時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人98時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.06527054905623281
# 個人98時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.9347294509437672
# 個人98時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.8147570032410055
# 個人98時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.18524299675899433
# 個人98時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.06527054905623278
# 個人98時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.9347294509437671
# 個人98時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.8147570032410056
# 個人98時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.18524299675899436
# 個人98時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user98，時刻3の一般化平均情報量6.862764520318781（正，小さい方がいい）
# 個人98時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人98時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.7541954274834352
# 個人98時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.24580457251656473
# 個人98時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人98時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人98時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.7541954274834353
# 個人98時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.24580457251656476
# 個人98時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user98，時刻4の一般化平均情報量8.383030165824819（正，小さい方がいい）
# 個人98時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人98時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人98時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人98時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user98，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人98時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人98時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user98，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人98時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user98，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人98時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user98，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# 個人99時刻0の25と1の同時滞在確率は0.893300055912458，同時発生尤度は0.9381765264201292
# 個人99時刻0の25と13の同時滞在確率は0.1066999440875422，同時発生尤度は0.061823473579870836
# user99，時刻0の一般化平均情報量0.24420156209649374（正，小さい方がいい）
# 個人99時刻1の1と2の同時滞在確率は0.7819833070121887，同時発生尤度は0.9349351401180336
# 個人99時刻1の1と14の同時滞在確率は0.06646449962568886，同時発生尤度は0.06506485988196643
# 個人99時刻1の13と4の同時滞在確率は0.5030695838717087，同時発生尤度は0.9185211238097115
# 個人99時刻1の13と17の同時滞在確率は0.16595058180761402，同時発生尤度は0.08147887619028847
# user99，時刻1の一般化平均情報量1.1837075160429995（正，小さい方がいい）
# 個人99時刻2の2と3の同時滞在確率は0.17064918115957614，同時発生尤度は0.5586862563842719
# 個人99時刻2の2と15の同時滞在確率は0.13598918239792193，同時発生尤度は0.441313743615728
# 個人99時刻2の4と5の同時滞在確率は0.4488667555429364，同時発生尤度は0.7559981867936847
# 個人99時刻2の4と18の同時滞在確率は0.26644119679633976，同時発生尤度は0.2440018132063152
# 個人99時刻2の14と5の同時滞在確率は0.32550978899995286，同時発生尤度は0.7559981867936848
# 個人99時刻2の14と18の同時滞在確率は0.19321818040448613，同時発生尤度は0.2440018132063152
# 個人99時刻2の17と7の同時滞在確率は0.6936730359580422，同時発生尤度は0.9589816212674429
# 個人99時刻2の17と21の同時滞在確率は0.15830236844024265，同時発生尤度は0.041018378732557044
# user99，時刻2の一般化平均情報量4.472619038864943（正，小さい方がいい）
# 個人99時刻3の3と16の同時滞在確率は0.37371292885537133，同時発生尤度は1.0
# 個人99時刻3の5と6の同時滞在確率は0.1696608652475173，同時発生尤度は0.41243164768886653
# 個人99時刻3の5と19の同時滞在確率は0.5061903522651732，同時発生尤度は0.5875683523111335
# 個人99時刻3の7と8の同時滞在確率は0.5188845677373513，同時発生尤度は0.9860239165340983
# 個人99時刻3の7と22の同時滞在確率は0.15579118938908587，同時発生尤度は0.013976083465901753
# 個人99時刻3の15と6の同時滞在確率は0.17866312394927222，同時発生尤度は0.4124316476888665
# 個人99時刻3の15と19の同時滞在確率は0.5330489710561099，同時発生尤度は0.5875683523111335
# 個人99時刻3の18と8の同時滞在確率は0.48474248877947534，同時発生尤度は0.9860239165340983
# 個人99時刻3の18と22の同時滞在確率は0.1455402869345038，同時発生尤度は0.013976083465901751
# 個人99時刻3の21と10の同時滞在確率は0.07428474119070608，同時発生尤度は1.0
# user99，時刻3の一般化平均情報量7.209611263361845（正，小さい方がいい）
# 個人99時刻4の6と20の同時滞在確率は0.11855623729132982，同時発生尤度は1.0
# 個人99時刻4の8と9の同時滞在確率は0.30328739524227843，同時発生尤度は0.6903335559005026
# 個人99時刻4の8と23の同時滞在確率は0.22043590954566292，同時発生尤度は0.30966644409949745
# 個人99時刻4の10と11の同時滞在確率は0.4706835538862136，同時発生尤度は1.0
# 個人99時刻4の16と20の同時滞在確率は0.3444378269627605，同時発生尤度は1.0
# 個人99時刻4の19と9の同時滞在確率は0.3247660449509503，同時発生尤度は0.6903335559005026
# 個人99時刻4の19と23の同時滞在確率は0.2360470617353592，同時発生尤度は0.30966644409949745
# 個人99時刻4の22と11の同時滞在確率は0.1413286722692466，同時発生尤度は1.0
# user99，時刻4の一般化平均情報量8.423783473843393（正，小さい方がいい）
# 個人99時刻5の9と24の同時滞在確率は0.33798107967625435，同時発生尤度は1.0
# 個人99時刻5の11と12の同時滞在確率は0.6665965631784282，同時発生尤度は1.0
# 個人99時刻5の20と24の同時滞在確率は0.5394894871560616，同時発生尤度は1.0
# 個人99時刻5の23と12の同時滞在確率は0.4448963801921564，同時発生尤度は1.0
# user99，時刻5の一般化平均情報量2.917381489402237（正，小さい方がいい）
# 個人99時刻6の12と26の同時滞在確率は0.907559030784908，同時発生尤度は1.0
# 個人99時刻6の24と26の同時滞在確率は0.9087045903861564，同時発生尤度は1.0
# user99，時刻6の一般化平均情報量0.19273188795840895（正，小さい方がいい）
# 個人99時刻7の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user99，時刻7の一般化平均情報量-0.0（正，小さい方がいい）
# 個人99時刻8の26と26の同時滞在確率は1.0，同時発生尤度は1.0
# user99，時刻8の一般化平均情報量-0.0（正，小さい方がいい）
# モデルパラメタ[-1.5  1.   0.8  2.  25. ]でのクロスエントロピー1952.5759308916458
# 1952.5759308916458
